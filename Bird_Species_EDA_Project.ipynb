# %% [markdown]
# # **Project Name**    -   **Bird Species Observation Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## Project Summary
#
# The Bird Species Observation Analysis project focuses on exploring and analyzing bird observation data collected from different habitats, locations, and time periods. The primary objective of the project is to understand bird diversity, habitat preferences, seasonal trends, and conservation status through data-driven insights.
#
# The project began with data cleaning and preprocessing, including handling missing values, merging datasets, removing inconsistencies, and creating new features such as Month and Season. Exploratory Data Analysis (EDA) was then performed to identify patterns and relationships within the data.
#
# Various visualizations were created to analyze top observed bird species, habitat diversity, seasonal bird activity, environmental impacts (temperature and humidity), flyover observations, and at-risk species. Correlation analysis was also conducted to understand the relationship between environmental factors and bird observations.
#
# An interactive Streamlit dashboard was developed to present key findings through KPI cards, filters, charts, and downloadable reports. The insights generated from this project can support wildlife researchers, conservation organizations, and environmental agencies in making informed decisions related to biodiversity monitoring, habitat management, and species conservation.
#
# Overall, the project demonstrates how exploratory data analysis and visualization techniques can be used to transform raw ecological data into meaningful insights for conservation and environmental sustainability.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The project aims to analyze the distribution and diversity of bird species in two distinct ecosystems: forests and grasslands. By examining bird species observations across these habitats, the goal is to understand how environmental factors, such as vegetation type, climate, and terrain, influence bird populations and their behavior. The study will involve working on the provided observational data of bird species present in both ecosystems, identifying patterns of habitat preference, and assessing the impact of these habitats on bird diversity. The findings can provide valuable insights into habitat conservation, biodiversity management, and the effects of environmental changes on avian communities.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze bird species observation data collected from forest and grassland ecosystems to understand patterns in species distribution, diversity, and habitat preferences. The project aims to identify how environmental factors such as temperature, humidity, weather conditions, and habitat type influence bird populations and behavior. By generating meaningful insights and visualizations, the study supports wildlife conservation, biodiversity monitoring, habitat management, and environmental decision-making. The findings can help conservation organizations and policymakers identify biodiversity hotspots, monitor at-risk species, and develop effective strategies for ecosystem preservation

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

df1 = pd.read_excel('/content/Bird_Monitoring_Data_FOREST.XLSX')
df2 = pd.read_excel('/content/Bird_Monitoring_Data_GRASSLAND.XLSX')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df1.head()
# Out:
#   Admin_Unit_Code  Sub_Unit_Code Site_Name  Plot_Name Location_Type  Year  \
# 0            ANTI            NaN    ANTI 1  ANTI-0036        Forest  2018
# 1            ANTI            NaN    ANTI 1  ANTI-0036        Forest  2018
# 2            ANTI            NaN    ANTI 1  ANTI-0036        Forest  2018
# 3            ANTI            NaN    ANTI 1  ANTI-0036        Forest  2018
# 4            ANTI            NaN    ANTI 1  ANTI-0036        Forest  2018
#
#         Date Start_Time  End_Time          Observer  ...  NPSTaxonCode  \
# 0 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...         83803
# 1 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...         90935
# 2 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...         84865
# 3 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...         93634
# 4 2018-05-22   06:19:00  06:29:00  Elizabeth Oswald  ...         88394
#
#   AOU_Code PIF_Watchlist_Status Regional_Stewardship_Status  Temperature  \
# ...

# %%
df2.head()
# Out:
#   Admin_Unit_Code  Sub_Unit_Code  Plot_Name Location_Type  Year       Date  \
# 0            ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 1            ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 2            ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 3            ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
# 4            ANTI            NaN  ANTI-0054     Grassland  2018 2018-05-22
#
#   Start_Time  End_Time          Observer  Visit  ... AOU_Code  \
# 0   05:35:00  05:45:00  Elizabeth Oswald      1  ...     CHSP
# 1   05:35:00  05:45:00  Elizabeth Oswald      1  ...     EABL
# 2   05:35:00  05:45:00  Elizabeth Oswald      1  ...     GRSP
# 3   05:35:00  05:45:00  Elizabeth Oswald      1  ...     EABL
# 4   05:35:00  05:45:00  Elizabeth Oswald      1  ...     FISP
#
#   PIF_Watchlist_Status Regional_Stewardship_Status  Temperature Humidity  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

df1.shape, df2.shape
# Out:
# ((333, 29), (3588, 29))

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Admin_Unit_Code              333 non-null    object
#  1   Sub_Unit_Code                0 non-null      float64
#  2   Site_Name                    333 non-null    object
#  3   Plot_Name                    333 non-null    object
#  4   Location_Type                333 non-null    object
#  5   Year                         333 non-null    int64
#  6   Date                         333 non-null    datetime64[ns]
#  7   Start_Time                   333 non-null    object
#  8   End_Time                     333 non-null    object
#  9   Observer                     333 non-null    object
#  10  Visit                        333 non-null    int64
#  11  Interval_Length              333 non-null    object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3588 entries, 0 to 3587
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Admin_Unit_Code              3588 non-null   object
#  1   Sub_Unit_Code                0 non-null      float64
#  2   Plot_Name                    3588 non-null   object
#  3   Location_Type                3588 non-null   object
#  4   Year                         3588 non-null   int64
#  5   Date                         3588 non-null   datetime64[ns]
#  6   Start_Time                   3588 non-null   object
#  7   End_Time                     3588 non-null   object
#  8   Observer                     3588 non-null   object
#  9   Visit                        3588 non-null   int64
#  10  Interval_Length              3588 non-null   object
#  11  ID_Method                    3587 non-null   object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

df1.duplicated().sum(), df2.duplicated().sum()
# Out:
# (np.int64(0), np.int64(458))

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

df1.isnull().sum(), df2.isnull().sum()
# Out:
# (Admin_Unit_Code                  0
#  Sub_Unit_Code                  333
#  Site_Name                        0
#  Plot_Name                        0
#  Location_Type                    0
#  Year                             0
#  Date                             0
#  Start_Time                       0
#  End_Time                         0
#  Observer                         0
#  Visit                            0
#  Interval_Length                  0
#  ID_Method                        0
#  Distance                         5
#  Flyover_Observed                 0
#  Sex                            221
#  Common_Name                      0
#  Scientific_Name                  0
#  AcceptedTSN                      1
#  NPSTaxonCode                     0
#  AOU_Code                         0
#  PIF_Watchlist_Status             0
#  Regional_Stewardship_Status      0
#  Temperature                      0
#  Humidity                         0
#  Sky                              0
# ...

# %%
# Visualizing the missing values

sns.heatmap(df1.isnull(), cbar=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df2.isnull(), cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset provides comprehensive information about bird observations across different habitats and environmental conditions. It offers an excellent opportunity to analyze species distribution, habitat preferences, environmental impacts, and conservation-related trends, which can support biodiversity conservation and ecological decision-making.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df1.columns, df2.columns
# Out:
# (Index(['Admin_Unit_Code', 'Sub_Unit_Code', 'Site_Name', 'Plot_Name',
#         'Location_Type', 'Year', 'Date', 'Start_Time', 'End_Time', 'Observer',
#         'Visit', 'Interval_Length', 'ID_Method', 'Distance', 'Flyover_Observed',
#         'Sex', 'Common_Name', 'Scientific_Name', 'AcceptedTSN', 'NPSTaxonCode',
#         'AOU_Code', 'PIF_Watchlist_Status', 'Regional_Stewardship_Status',
#         'Temperature', 'Humidity', 'Sky', 'Wind', 'Disturbance',
#         'Initial_Three_Min_Cnt'],
#        dtype='object'),
#  Index(['Admin_Unit_Code', 'Sub_Unit_Code', 'Plot_Name', 'Location_Type',
#         'Year', 'Date', 'Start_Time', 'End_Time', 'Observer', 'Visit',
#         'Interval_Length', 'ID_Method', 'Distance', 'Flyover_Observed', 'Sex',
#         'Common_Name', 'Scientific_Name', 'AcceptedTSN', 'TaxonCode',
#         'AOU_Code', 'PIF_Watchlist_Status', 'Regional_Stewardship_Status',
#         'Temperature', 'Humidity', 'Sky', 'Wind', 'Disturbance',
# ...

# %%
# Dataset Describe

df1.describe()
# Out:
#        Sub_Unit_Code    Year                           Date       Visit  \
# count            0.0   333.0                            333  333.000000
# mean             NaN  2018.0  2018-06-09 06:37:50.270270208    1.507508
# min              NaN  2018.0            2018-05-22 00:00:00    1.000000
# 25%              NaN  2018.0            2018-05-24 00:00:00    1.000000
# 50%              NaN  2018.0            2018-06-25 00:00:00    2.000000
# 75%              NaN  2018.0            2018-06-26 00:00:00    2.000000
# max              NaN  2018.0            2018-06-26 00:00:00    2.000000
# std              NaN     0.0                            NaN    0.500696
#
#          AcceptedTSN   NPSTaxonCode  Temperature    Humidity
# count     332.000000     333.000000   333.000000  333.000000
# mean   218567.036145  112177.567568    21.873273   71.366067
# min    176136.000000   82737.000000    14.000000   49.599998
# 25%    178359.000000   85791.000000    17.900000   61.200001
# ...

# %%
df2.describe()
# Out:
#        Sub_Unit_Code    Year                           Date        Visit  \
# count            0.0  3588.0                           3588  3588.000000
# mean             NaN  2018.0  2018-06-19 14:47:21.471571968     1.941472
# min              NaN  2018.0            2018-05-22 00:00:00     1.000000
# 25%              NaN  2018.0            2018-05-24 00:00:00     1.000000
# 50%              NaN  2018.0            2018-06-25 00:00:00     2.000000
# 75%              NaN  2018.0            2018-07-13 00:00:00     3.000000
# max              NaN  2018.0            2018-07-19 00:00:00     3.000000
# std              NaN     0.0                            NaN     0.817584
#
#          AcceptedTSN      TaxonCode  Temperature     Humidity
# count    3568.000000    3587.000000  3588.000000  3588.000000
# mean   196047.088285  102455.164483    24.176672    68.493896
# min    174999.000000   76625.000000    12.900000    32.900002
# 25%    178581.000000   84790.000000    21.200001    58.599998
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Variable Name =>	Description
#
# Admin_Unit_Code =>	Code of the administrative unit where the observation was conducted.
#
# Sub_Unit_Code	=> Sub-classification code within the administrative unit.
#
# Site_Name	=> Name of the observation site.
#
# Plot_Name =>	Unique identifier of the observation plot.
#
# Location_Type =>	Type of habitat where observation was recorded (Forest/Grassland).
#
# Year =>	Year in which the observation was made.
#
# Date =>	Exact date of observation.
#
# Start_Time	=> Start time of the observation session.
#
# End_Time =>	End time of the observation session.
#
# Observer =>	Name or ID of the person conducting the observation.
#
# Visit =>	Number of visits made to the same site or plot.
#
# Interval_Length =>	Duration of the observation interval.
#
# ID_Method	=> Method used to identify the bird species (e.g., Singing, Calling, Visual Observation).
#
# Distance =>	Distance between observer and bird.
#
# Flyover_Observed =>	Indicates whether the bird was observed flying overhead (TRUE/FALSE).
#
# Sex	=> Gender of the observed bird (Male/Female/Undetermined).
#
# Common_Name	=> Common name of the bird species.
#
# Scientific_Name =>	Scientific name of the bird species.
#
# AcceptedTSN	Taxonomic => Serial Number assigned to the species.
#
# NPSTaxonCode =>	Unique taxonomic code used by the National Park Service.
#
# AOU_Code =>	American Ornithological Union species code.
#
# PIF_Watchlist_Status =>	Indicates whether the species is listed as a conservation concern.
#
# Regional_Stewardship_Status =>	Indicates regional conservation priority status.
#
# Temperature =>	Temperature recorded during observation (°F/°C as per dataset).
#
# Humidity =>	Humidity percentage recorded during observation.
#
# Sky	=> Sky condition during observation (e.g., Clear, Cloudy).
#
# Wind =>	Wind condition during observation.
#
# Disturbance	=> Any disturbance that may affect bird observations.
#
# Initial_Three_Min_Cnt =>	Number of birds observed within the first three minutes of the survey.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

df1.nunique().sum(), df2.nunique().sum()
# Out:
# (np.int64(388), np.int64(1216))

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

df = pd.concat([df1, df2], ignore_index=True)

df['Temperature'].fillna(df['Temperature'].median(), inplace=True)

df['Humidity'].fillna(df['Humidity'].median(), inplace=True)

df['Sex'].fillna('Unknown', inplace=True)

df['Date'] = pd.to_datetime(df['Date'])

df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Season'] = df['Date'].dt.quarter

df['ID_Method'].fillna(df['ID_Method'].mode()[0], inplace=True)

df['Distance'].fillna(df['Distance'].mode()[0], inplace=True)

df['AcceptedTSN'] = df.groupby('Scientific_Name')['AcceptedTSN'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x)
)

df['TaxonCode'].fillna(df['TaxonCode'].mode()[0], inplace=True)

df['Previously_Obs'].fillna(False, inplace=True)

df['Site_Name'].fillna('Unknown Site', inplace=True)

df['NPSTaxonCode'].fillna('Unknown', inplace=True)

df['Sub_Unit_Code'].fillna('Not Available', inplace=True)

df['AcceptedTSN'].fillna(
    df['AcceptedTSN'].mode()[0],
    inplace=True
)

df.drop_duplicates()

df.isnull().sum()
# Out:
# Admin_Unit_Code                0
# Sub_Unit_Code                  0
# Site_Name                      0
# Plot_Name                      0
# Location_Type                  0
# Year                           0
# Date                           0
# Start_Time                     0
# End_Time                       0
# Observer                       0
# Visit                          0
# Interval_Length                0
# ID_Method                      0
# Distance                       0
# Flyover_Observed               0
# Sex                            0
# Common_Name                    0
# Scientific_Name                0
# AcceptedTSN                    0
# NPSTaxonCode                   0
# AOU_Code                       0
# PIF_Watchlist_Status           0
# Regional_Stewardship_Status    0
# Temperature                    0
# Humidity                       0
# Sky                            0
# Wind                           0
# Disturbance                    0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# # **Manipulations Performed**
# * Merged all Excel sheets into a single dataset.
# * Checked and handled missing values using mode, placeholders (Unknown, -1), and species-wise filling.
# * Removed duplicate records.
# * Converted Date column to datetime format.
# * Created new features: Month and Season.
# # **Standardized categorical values and verified data quality.**
# * Key Insights During Data Wrangling
# * Most important analytical columns (species, date, weather, location) had no missing values.
# * Missing values were mainly present in identifier/taxonomy columns like NPSTaxonCode and AcceptedTSN.
# * The dataset was largely clean and suitable for analysis after minimal preprocessing.
# * Data supports temporal, habitat, environmental, and conservation-related analysis.

# %%
import sqlite3

conn = sqlite3.connect("birds.db")

df.to_sql("bird_observations",
          conn,
          if_exists="replace",
          index=False)
# Out:
# 3921

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

top_species = df['Common_Name'].value_counts().head(10)

plt.figure(figsize=(12,6))
top_species.plot(kind='bar')

plt.title('Top 10 Most Observed Bird Species')
plt.xlabel('Bird Species')
plt.ylabel('Observation Count')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it is the most effective way to compare observation frequencies across different bird species and identify dominant species.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# # **Insights Found**
#
# * A few bird species account for a large percentage of total observations.
# * Some species are consistently observed across multiple locations.
# * Several species have significantly lower observation frequencies, indicating rarity or habitat specialization.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Business Impact**
#
# * Helps conservation agencies identify common and rare species.
# * Supports biodiversity monitoring and habitat management.
# * Rare species may require additional protection measures.
#
# # **Negative Insight**
#
# * If observation counts are heavily concentrated among a few species, it may indicate reduced biodiversity and possible ecological imbalance within certain habitats.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

habitat_diversity = df.groupby('Location_Type')['Scientific_Name'].nunique().reset_index()

plt.figure(figsize=(8,5))

sns.barplot(
    data=habitat_diversity,
    x='Location_Type',
    y='Scientific_Name'
)

plt.title('Bird Species Diversity by Habitat')
plt.xlabel('Habitat Type')
plt.ylabel('Unique Species Count')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing species diversity across different habitat types. It clearly shows which habitat supports a greater number of unique bird species.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * One habitat (Forest or Grassland) contains a higher number of unique bird species.
# * Habitats with greater diversity act as biodiversity hotspots.
# * Species distribution is not uniform across habitats.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps conservation organizations prioritize habitat protection.
# * Assists wildlife managers in identifying ecologically important regions.
# * Supports biodiversity monitoring and environmental planning.
# # **Negative Insight**
#
# If one habitat shows significantly lower species diversity:
#
# * It may indicate habitat degradation.
# * Environmental conditions may be unfavorable for many species.
# * Conservation efforts may be required to restore ecological balance.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

monthly_obs = df.groupby('Month').size().reset_index(name='Observations')

plt.figure(figsize=(10,5))

sns.lineplot(
    data=monthly_obs,
    x='Month',
    y='Observations',
    marker='o'
)

plt.title('Monthly Bird Observation Trend')
plt.xlabel('Month')
plt.ylabel('Number of Observations')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is best for showing trends over time. Since months are ordered chronologically, a line chart helps visualize increases and decreases in bird observations throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Bird observations peak during certain months.
# * Some months record fewer sightings.
# * Seasonal patterns and possible migration periods can be identified.
# * Bird activity varies throughout the year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps wildlife authorities schedule surveys during peak activity periods.
# * Supports planning for conservation programs.
# * Helps researchers study migration and breeding seasons.
# * Useful for eco-tourism and bird-watching activities.
# Negative Insight
# # **bold text**
# If observations decline sharply during certain months:
#
# * It may indicate habitat disturbance.
# * Seasonal environmental stress may affect bird populations.
# * Certain species may be leaving the region due to unfavorable conditions.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x='Temperature',
    y='Initial_Three_Min_Cnt'
)

plt.title('Temperature vs Bird Activity')
plt.xlabel('Temperature')
plt.ylabel('Bird Count (Initial Three Minutes)')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for studying the relationship between two numerical variables:
#
# * Temperature
# * Bird Count
#
# It helps identify whether bird activity increases, decreases, or remains unchanged with temperature.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Bird activity may be higher at moderate temperatures.
# * Extremely high or low temperatures may show fewer bird sightings.
# * The chart reveals whether a correlation exists between temperature and bird observations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps researchers determine favorable environmental conditions for bird activity.
# * Supports planning of bird surveys during optimal weather conditions.
# * Assists conservationists in understanding climate effects on bird populations.
# # **Negative Insight**
#
# If bird observations decrease significantly at higher temperatures:
#
# * It may indicate climate-related stress on bird populations.
# * Future temperature increases could negatively impact biodiversity.
# * Conservation measures may be needed to protect vulnerable species.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
df['Humidity_Level'] = pd.cut(
    df['Humidity'],
    bins=[0, 30, 60, 100],
    labels=['Low', 'Medium', 'High']
)

plt.figure(figsize=(8,5))

sns.boxplot(
    x='Humidity_Level',
    y='Initial_Three_Min_Cnt',
    data=df
)

plt.title('Bird Activity Across Humidity Levels')
plt.xlabel('Humidity Level')
plt.ylabel('Bird Count')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is useful for comparing the distribution of bird counts across different humidity levels. It helps identify:
#
# * Median bird activity
# * Variability in observations
# * Outliers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Bird activity may be higher under specific humidity conditions.
# * Some humidity ranges show more consistent bird sightings.
# * Extreme humidity levels may result in lower bird activity.
# * Outliers indicate unusually high or low bird observations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps researchers understand the influence of humidity on bird behavior.
# * Supports better planning of wildlife surveys.
# * Assists conservation agencies in predicting bird activity under different environmental conditions.
# # **Negative Insight**
#
# If bird counts drop significantly at very high or very low humidity:
#
# * Certain species may be sensitive to environmental changes.
# * Climate fluctuations could affect bird populations.
# * Habitat conditions may become less suitable for some species.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

sex_counts = df['Sex'].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    sex_counts,
    labels=sex_counts.index,
    autopct='%1.1f%%'
)

plt.title('Sex Distribution of Observed Birds')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is suitable because it shows the proportion of different categories (Male, Female, Unknown) within the total observations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The majority of observations belong to a particular sex category.
# * Some observations may have unknown sex.
# * The population structure of observed birds can be understood.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps researchers understand population demographics.
# * Supports breeding and conservation studies.
# * Useful for monitoring species reproduction patterns.
# # **Negative Insight**
#
# If one sex is significantly underrepresented:
#
# * It may indicate observation bias.
# * It could suggest ecological or reproductive concerns within certain species.
# * Further investigation may be required.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

flyover_counts = df['Flyover_Observed'].value_counts().reset_index()
flyover_counts.columns = ['Flyover_Observed', 'Count']

plt.figure(figsize=(6,4))

sns.barplot(
    data=flyover_counts,
    x='Flyover_Observed',
    y='Count'
)

plt.title('Flyover Observations')
plt.xlabel('Flyover Observed')
plt.ylabel('Number of Observations')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing the number of flyover observations against non-flyover observations. It clearly highlights differences between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most observations may belong to either flyover or non-flyover birds.
# * Helps understand bird movement patterns.
# * Indicates whether birds are primarily using the habitat for feeding/resting or simply passing through.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps wildlife managers understand habitat utilization.
# * Supports conservation planning for migratory birds.
# * Assists researchers in identifying important movement corridors.
# # **Negative Insight**
#
# If flyover observations dominate:
#
# * Birds may not be spending much time in the habitat.
# * The habitat may be acting only as a transit route rather than a suitable living environment.
# * This could indicate habitat quality concerns.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

watchlist_counts = df['PIF_Watchlist_Status'].value_counts().reset_index()
watchlist_counts.columns = ['Watchlist_Status', 'Count']

plt.figure(figsize=(6,4))

sns.barplot(
    data=watchlist_counts,
    x='Watchlist_Status',
    y='Count'
)

plt.title('At-Risk Species Distribution')
plt.xlabel('PIF Watchlist Status')
plt.ylabel('Number of Observations')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is effective for comparing the number of observations belonging to watchlist (at-risk) and non-watchlist species.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Identifies the proportion of at-risk bird species in the dataset.
# * Highlights the presence of conservation-priority species.
# * Helps determine whether vulnerable species are frequently observed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Supports biodiversity conservation planning.
# * Helps environmental agencies prioritize species protection.
# * Assists in allocating resources toward vulnerable bird populations.
# * Enables monitoring of species at risk of decline.
# # **Negative Insight**
#
# If the number of at-risk species is high:
#
# * It may indicate environmental stress or habitat degradation.
# * Several species could be facing population decline.
# * Immediate conservation measures may be required.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

top_observers = (
    df['Observer']
    .value_counts()
    .head(10)
    .reset_index()
)

top_observers.columns = ['Observer', 'Observations']

plt.figure(figsize=(12,6))

sns.barplot(
    data=top_observers,
    x='Observations',
    y='Observer'
)

plt.title('Top 10 Observers by Number of Bird Observations')
plt.xlabel('Number of Observations')
plt.ylabel('Observer')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is ideal for comparing observation counts among different observers and identifying the most active contributors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some observers contributed significantly more observations than others.
# * Survey effort is not evenly distributed across observers.
# * A small group of observers may account for a large portion of the data collected.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Yes.**
#
# * Helps evaluate survey participation and effort.
# * Identifies experienced observers who contribute valuable data.
# * Assists project managers in allocating survey resources effectively.
# # **Negative Insigh**t
#
# If a few observers contribute most of the observations:
#
# * Observer bias may exist.
# * Results may be influenced by individual observation habits.
# * Additional observer training and balanced survey participation may be needed.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

seasonal_obs = (
    df.groupby('Season')
    .size()
    .reset_index(name='Observations')
)

plt.figure(figsize=(8,5))

sns.barplot(
    data=seasonal_obs,
    x='Season',
    y='Observations'
)

plt.title('Seasonal Bird Activity')
plt.xlabel('Season')
plt.ylabel('Number of Observations')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare bird activity across seasons and identify peak observation periods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Certain seasons show higher bird activity than others.
# * Seasonal changes strongly influence bird presence and behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Business Impact**
# * Helps schedule wildlife surveys and conservation activities during peak seasons.
# * Supports migration and breeding season analysis.
# # **Negative Insight**
#
# * A sharp decline in observations during specific seasons may indicate habitat disturbance, migration away from the area, or unfavorable environmental conditions.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Select numerical columns
numerical_cols = [
    'Year',
    'Temperature',
    'Humidity',
    'Initial_Three_Min_Cnt'
]

corr_matrix = df[numerical_cols].corr()

plt.figure(figsize=(8,6))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is useful for visualizing correlations between multiple numerical variables simultaneously. It quickly identifies strong positive, negative, or weak relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Shows how Temperature and Humidity are related.
# * Reveals whether bird activity (Initial_Three_Min_Cnt) increases or decreases with environmental conditions.
# * Helps identify variables that have the strongest influence on bird observations.
# * Detects multicollinearity between features.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

numerical_cols = [
    'Temperature',
    'Humidity',
    'Initial_Three_Min_Cnt',
    'Year'
]

sns.pairplot(
    df[numerical_cols],
    diag_kind='hist'
)

plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen because it allows simultaneous exploration of relationships among multiple numerical variables. Instead of creating several scatter plots separately, it provides a comprehensive view in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Reveals relationships between Temperature, Humidity, and Bird Count.
# * Identifies whether bird activity increases or decreases under certain environmental conditions.
# * Highlights outliers and unusual observations.
# * Shows the distribution of each numerical variable.

# %%
df.to_csv("cleaned_bird_data.csv", index=False)

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 61.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 97.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -q streamlit pyngrok

# %%
code = """

import streamlit as st

import plotly.express as px

# %%writefile app.py

# -------------------------
# Page Config
# -------------------------
st.set_page_config(
    page_title="Bird Species Observation Dashboard",
    page_icon="🦜",
    layout="wide"
)

# -------------------------
# Load Data
# -------------------------
df = pd.read_csv("cleaned_bird_data.csv")

# -------------------------
# Sidebar Filters
# -------------------------
st.sidebar.header("Filters")

species = st.sidebar.selectbox(
    "Select Species",
    ["All"] + sorted(df["Common_Name"].unique().tolist())
)

selected_habitat = st.sidebar.multiselect(
    "Habitat",
    df["Location_Type"].unique(),
    default=df["Location_Type"].unique()
)

selected_season = st.sidebar.multiselect(
    "Season",
    df["Season"].unique(),
    default=df["Season"].unique()
)

# Apply Filters
filtered_df = df.copy()

if species != "All":
    filtered_df = filtered_df[
        filtered_df["Common_Name"] == species
    ]

filtered_df = filtered_df[
    filtered_df["Location_Type"].isin(selected_habitat)
]

filtered_df = filtered_df[
    filtered_df["Season"].isin(selected_season)
]

# -------------------------
# Title
# -------------------------
st.title("🦜 Bird Species Observation Dashboard")

st.markdown('''
Analyze bird observations, habitats,
environmental conditions and conservation insights.
''')

# -------------------------
# Download Button
# -------------------------
csv = filtered_df.to_csv(index=False)

st.download_button(
    "📥 Download Filtered Data",
    csv,
    "bird_analysis.csv",
    "text/csv"
)

# -------------------------
# KPI Cards
# -------------------------
col1, col2, col3, col4 = st.columns(4)

col1.metric(
    "Observations",
    len(filtered_df)
)

col2.metric(
    "Species",
    filtered_df["Scientific_Name"].nunique()
)

col3.metric(
    "Habitats",
    filtered_df["Location_Type"].nunique()
)

col4.metric(
    "Observers",
    filtered_df["Observer"].nunique()
)

# -------------------------
# Dataset Preview
# -------------------------
st.subheader("Dataset Preview")
st.dataframe(filtered_df.head(), width="stretch")

# -------------------------
# Top Species
# -------------------------
st.subheader("Top 10 Bird Species")

top_species = (
    filtered_df["Common_Name"]
    .value_counts()
    .head(10)
    .reset_index()
)

top_species.columns = [
    "Species",
    "Observations"
]

fig = px.bar(
    top_species,
    x="Observations",
    y="Species",
    orientation="h"
)

st.plotly_chart(fig, width="stretch")

# -------------------------
# Habitat Analysis
# -------------------------
st.subheader("Habitat Diversity")

habitat = (
    filtered_df
    .groupby("Location_Type")
    ["Scientific_Name"]
    .nunique()
    .reset_index()
)

fig = px.bar(
    habitat,
    x="Location_Type",
    y="Scientific_Name"
)

st.plotly_chart(fig, width="stretch")

# -------------------------
# Temperature Analysis
# -------------------------
st.subheader("Temperature vs Bird Count")

fig = px.scatter(
    filtered_df,
    x="Temperature",
    y="Initial_Three_Min_Cnt",
    color="Location_Type"
)

st.plotly_chart(fig, width="stretch")

# -------------------------
# Conservation Analysis
# -------------------------
st.subheader("Conservation Status")

watchlist = (
    filtered_df["PIF_Watchlist_Status"]
    .value_counts()
    .reset_index()
)

watchlist.columns = ["Status", "Count"]

fig = px.pie(
    watchlist,
    values="Count",
    names="Status"
)

st.plotly_chart(fig, width="stretch")

# -------------------------
# Monthly Trend
# -------------------------
st.subheader("Monthly Trend")

monthly = (
    filtered_df
    .groupby("Month")
    .size()
    .reset_index(name="Observations")
)

fig = px.line(
    monthly,
    x="Month",
    y="Observations",
    markers=True
)

st.plotly_chart(fig, width="stretch")

# -------------------------
# Footer
# -------------------------
st.markdown("---")

st.markdown('''
### Project Summary

✔ Species Diversity Analysis
✔ Habitat Comparison
✔ Environmental Analysis
✔ Conservation Monitoring
✔ Seasonal Trends

Built with Streamlit, Pandas and Plotly.
''')
"""
with open("app.py", "w") as f:
    f.write(code)

# %%
import os

os.makedirs(".streamlit", exist_ok=True)

with open(".streamlit/config.toml", "w") as f:
    f.write("""
[theme]
base="dark"
primaryColor="#4CAF50"
backgroundColor="#0E1117"
secondaryBackgroundColor="#262730"
textColor="#FAFAFA"
""")

# %%
import os

print(os.listdir(".streamlit"))
# Out:
# ['config.toml']

# %%
# !streamlit run app.py &>/content/logs.txt &

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# # **Recommendations to Achieve Business Objectives**
# 1. **Prioritize Habitat Conservation**
#   * Focus protection efforts on habitats showing the highest bird species diversity, as these areas contribute most to biodiversity preservation.
# 2. **Monitor At-Risk Species Regularly**
# * Implement targeted monitoring programs for species listed in conservation watchlists to detect population declines early.
# 3. **Schedule Surveys During Peak Activity Periods**
# * Conduct observations during seasons and months with the highest bird activity to improve data quality and survey efficiency.
# 4. **Use Environmental Data for Planning**
# Consider temperature and humidity patterns when planning conservation activities, as environmental conditions influence bird observations.
# 5. **Improve Data-Driven Decision Making**
# * Use dashboard insights to allocate conservation resources, prioritize habitats, and track biodiversity trends over time.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### Conclusion
#
# This project analyzed bird species observation data to understand biodiversity patterns, habitat preferences, seasonal trends, and environmental influences on bird activity. Through data cleaning, exploratory data analysis, and interactive visualizations, key insights were identified regarding species distribution, habitat diversity, conservation status, and the impact of weather conditions on bird observations.
#
# The findings can help wildlife researchers and conservation agencies make informed decisions for habitat management, biodiversity monitoring, and protection of at-risk species. Overall, the project demonstrates how data-driven analysis can support effective conservation planning and ecological sustainability.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
